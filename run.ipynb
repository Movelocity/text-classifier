# %% [markdown]
# ## 1. 加载模型

# %%
from models.roberta_classifier import Roberta_Model

roberta_base = r"C:\projects\models\roberta-base"
lora_path = r"C:\projects\models\roberta-base\lora-2024-11-11.zip"
model = Roberta_Model(roberta_base, lora_path=lora_path, device="cpu")
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at C:\projects\models\roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# load lora model: C:\projects\models\roberta-base\lora-2024-11-11.zip
# Unzipped model to `c:\projects\legacy_projects\text-classifier\.temp`
# load model `C:\projects\models\roberta-base` with lora `None`

# %% [markdown]
# ## 2. 模型推理

# %%
model.infer("hello, how much is the shoe?")
# Out:
# {'productRequest': 0.37547796964645386, 'askWeight': 0.31110990047454834}

# %%
print(model.infer("hello, how much is the freight?"))
# Out:
# {'askPostage': 0.9463841319084167}

# %%
print(model.infer("give me a brand of cat food"))
# Out:
# {'relatedProducts': 0.7661340236663818}

# %%
print(model.infer("is there any dress that fits size 6?"))
# Out:
# {'requestSize': 0.29428085684776306}
